# %%
import numpy as np
import pandas as pd

class FXTrading:
    def __init__(self, fx_rates, real_fx_rates):
        """
        Initialize the FXTrading simulation environment.

        Args:
            fx_rates (numpy array): Predicted FX rates (3, N)
            real_fx_rates (numpy array): Real FX rates (3, N)
        """
        self.Pre_fx_rates = fx_rates
        self.real_fx_rates = real_fx_rates
        self.day = 0
        self.start = len(fx_rates[0]) - 1  # Starting point in the time series

        self.initial_capital = np.array([1000, 1000, 1000], dtype=float)  # 「三種貨幣交易帳戶的初始資金」各為 $1000(Initial capital for 3 currencies)
        self.capital = np.array([1000, 1000, 1000], dtype=float)  # 當前資金(Current capital)
        self.available_margin = self.capital  # 可動用的保證金額度(Available margin)

        self.leverage = np.array([5, 5, 5])  # Leverage for each currency (can be changed when opening positions)
        self.position_size = np.array([0, 0, 0], dtype=float)  # 三種貨幣目前的持倉數量（張數/單位）Current position size (positive=long, negative=short)
        self.position_value = np.array([0, 0, 0], dtype=float)  # 三種貨幣當前持倉的總市值（含槓桿）Current position value
        self.floating_pnl = np.array([0, 0, 0], dtype=float)  # 因為市場價格波動而產生的帳面盈虧(Current floating profit and loss)
        self.now_price = np.array([
            real_fx_rates[0][self.start],
            real_fx_rates[1][self.start],
            real_fx_rates[2][self.start]
        ], dtype=float)  # Current market price
        self.entry_price = np.array([0, 0, 0], dtype=float)  # 進場價格（建倉時的價格）(Entry price of the current position)
        self.margin = 10  # 每單位倉位需要的初始保證金(Margin required per position)

        self.model = None  # Placeholder for custom prediction model

    # 確認是否需要強制平倉
    def check_liquidation(self, cap_num, maintenance_margin_ratio_threshold=0.3):
        """
        Check if the position should be liquidated (trigger forced liquidation).

        Args:
            cap_num (int): Index of the currency (0, 1, 2)
            maintenance_margin_ratio_threshold (float): Liquidation threshold (default 30%)

        Returns:
            bool: True if should liquidate, False otherwise
        """
        equity = self.capital[cap_num] + self.floating_pnl[cap_num] # ex : 2500 = 3000 + (-500)

        if equity / (self.margin * abs(self.position_size[cap_num])) < maintenance_margin_ratio_threshold:
            return True

        return False
    
    # 平倉一筆倉位，並計算其實現損益（Realized PnL）
    def close_position(self, cap_num, close_price):
        """
        Close the position and calculate realized PnL.

        Args:
            cap_num (int): Index of the currency
            close_price (float): Current market price

        Returns:
            float: Realized PnL(非浮動損益)
        """
        return (close_price - self.entry_price[cap_num]) * self.position_size[cap_num] * self.margin * self.leverage[cap_num] / close_price

    def predict_fx_rate(self, data): #Needs to be designed manually
        """
        Predict the next FX rate. User should implement their own model.

        Args:
            data (any): Input features for prediction.

        Returns:
            None: Updates self.Pre_fx_rates
        """
        # Random prediction example:
        a = np.random.choice(self.Pre_fx_rates[0])
        b = np.random.choice(self.Pre_fx_rates[1])
        c = np.random.choice(self.Pre_fx_rates[2])
        fx_rate = np.array([[a], [b], [c]])

        # Update Pre_fx_rates by appending new prediction
        self.Pre_fx_rates = np.concatenate([self.Pre_fx_rates, fx_rate], axis=1)

    def open_position(self, cap_num, any): #Needs to be designed manually
        """
        Decide how to open a position.

        Args:
            cap_num (int): Index of the currency

        Returns:
            (int, float): (action, number of lots)
                action: 0 = LONG, 1 = SHORT, 2 = HOLD
                buy_num: number of lots
        """
        action = 1
        buy_num = 10

        return action, buy_num

    def decide_action(self, any): #Needs to be designed manually
        """
        Decide what to do with an existing position.

        Returns:
            (int, float): (action, number of lots)
                action: 0 = ADD, 1 = CLOSE, 2 = HOLD
        """
        action = 2
        buy_num = 1

        return action, buy_num

    def update_entry_price(self, cap_num, add_price, old_position, add_position):
        """
        Update the average entry price after adding position.

        Args:
            cap_num (int): Index of the currency
            add_price (float): Price of new added position
            old_position (float): Previous position size
            add_position (float): New added position size
        """
        old_value = abs(old_position) * self.margin * self.leverage[cap_num]
        add_value = abs(add_position) * self.margin * self.leverage[cap_num]

        self.entry_price[cap_num] = (self.entry_price[cap_num] * old_value + add_price * add_value) / (old_value + add_value)

    def update(self):
        """
        Update environment for current day (prices, margins, PnL, position value).
        """
        self.now_price = np.array([
            self.real_fx_rates[0][self.start + self.day],
            self.real_fx_rates[1][self.start + self.day],
            self.real_fx_rates[2][self.start + self.day]
        ])

        self.available_margin = self.capital - abs(self.position_size) * self.margin
        self.position_value = abs(self.margin * self.position_size * self.leverage)
        self.floating_pnl = self.position_size * (self.now_price - self.entry_price) * self.leverage * self.margin / self.now_price

    def run_days(self, max_days=None):
        """
        Run simulation over multiple days.

        Args:
            max_days (int): Number of days to run
        """
        for day in range(max_days):
            self.day = day
            self.update()
            self.predict_fx_rate(None) #

            # Print current state
            print("Day ", day + 1)
            print(" ")

            for i, name in enumerate(["USD/JPY", "USD/EUR", "USD/GBP"]):
                print(name + ":")
                print("Pre_fx_rate: ", self.Pre_fx_rates[i][day + self.start], "real_fx_rates: ", self.now_price[i])
                print("Capital: ", self.capital[i], "available_margin: ", self.available_margin[i], "position_size: ", self.position_size[i], "leverage: ", self.leverage[i])
                print("floating_pnl: ", self.floating_pnl[i], "entry_price: ", self.entry_price[i], "position_value: ", self.position_value[i])
                print(" ")

            # Main trading loop for each currency
            for cap_num in range(3):
                # Check for liquidation
                if self.position_size[cap_num] != 0 and self.check_liquidation(cap_num):
                    print("Liquidation triggered!")
                    self.capital[cap_num] += self.close_position(cap_num, self.now_price[cap_num])
                    self.position_size[cap_num] = 0

                # If no position, try to open new position
                if self.position_size[cap_num] == 0 and self.capital[cap_num] > 0:
                    action, num = self.open_position(cap_num, None)
                    if action == 0 and num * self.margin <= self.available_margin[cap_num]:
                        self.position_size[cap_num] += num
                        self.entry_price[cap_num] = self.now_price[cap_num]
                    elif action == 1 and num * self.margin <= self.available_margin[cap_num]:
                        self.entry_price[cap_num] = self.now_price[cap_num]
                        self.position_size[cap_num] -= num
                else:
                    # If position exists, decide what to do
                    action, num = self.decide_action(None)

                    if action == 0:  # ADD position
                        self.update_entry_price(cap_num, self.now_price[cap_num], self.position_size[cap_num], num)
                        self.position_size[cap_num] += num
                    elif action == 1:  # CLOSE position
                        self.capital[cap_num] += self.close_position(cap_num, self.now_price[cap_num])
                        self.position_size[cap_num] = 0

        # Final update after run
        self.capital += self.position_size * (self.now_price - self.entry_price) * self.leverage * self.margin / self.now_price
        print("Final Results:")
        print("USD/JPY:  capital", self.capital[0])
        print("USD/EUR:  capital", self.capital[1])
        print("USD/GBP:  capital", self.capital[2])
        print("Rate of Return: ", sum(self.capital) / sum(self.initial_capital))

# %% [markdown]
# **Run the simulation**

# %%
df1 = pd.read_excel('fx_data.xlsx')
fx_data = df1.values  # or df.to_numpy()
fx_data = fx_data.T  # (3, N)

df2 = pd.read_excel('fake_fx_data.xlsx')
real_fx_data = df2.values
real_fx_data = real_fx_data.T

#fx_rates and real_fx_rates inputs need to be NumPy arrays of shape (3, N)
env = FXTrading(fx_rates = fx_data, real_fx_rates = real_fx_data)
env.run_days(max_days = 50)
# Out:
# Day  1
#
# USD/JPY:
# Pre_fx_rate:  146.6990051269531 real_fx_rates:  138.5980072
# Capital:  1000.0 available_margin:  1000.0 position_size:  0.0 leverage:  5
# floating_pnl:  0.0 entry_price:  0.0 position_value:  0.0
#
# USD/EUR:
# Pre_fx_rate:  0.9020000100135803 real_fx_rates:  0.928529978
# Capital:  1000.0 available_margin:  1000.0 position_size:  0.0 leverage:  5
# floating_pnl:  0.0 entry_price:  0.0 position_value:  0.0
#
# USD/GBP:
# Pre_fx_rate:  0.7698000073432922 real_fx_rates:  0.805329978
# Capital:  1000.0 available_margin:  1000.0 position_size:  0.0 leverage:  5
# floating_pnl:  0.0 entry_price:  0.0 position_value:  0.0
#
# Day  2
#
# USD/JPY:
# Pre_fx_rate:  115.1210021972656 real_fx_rates:  139.2830048
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.4590135780872178 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9108499884605408 real_fx_rates:  0.9296
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.5755281841652046 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.832099974155426 real_fx_rates:  0.808340013
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -1.8618619340819873 entry_price:  0.805329978 position_value:  500.0
#
# Day  3
#
# USD/JPY:
# Pre_fx_rate:  150.0980072021484 real_fx_rates:  140.0169983
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -5.067210114587921 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9165499806404114 real_fx_rates:  0.932449996
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.101999043817879 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8222399950027466 real_fx_rates:  0.811800003
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.984987051053291 entry_price:  0.805329978 position_value:  500.0
#
# Day  4
#
# USD/JPY:
# Pre_fx_rate:  124.0960006713867 real_fx_rates:  140.8710022
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -8.067646870194483 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.948170006275177 real_fx_rates:  0.932569981
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.166058892260204 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7283499836921692 real_fx_rates:  0.809920013
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.8336347579548593 entry_price:  0.805329978 position_value:  500.0
#
# Day  5
#
# USD/JPY:
# Pre_fx_rate:  113.7649993896484 real_fx_rates:  140.4409943
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -6.561428552916432 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.92194002866745 real_fx_rates:  0.933910012
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.8803813701913596 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.727869987487793 real_fx_rates:  0.809759974
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.7353760016792625 entry_price:  0.805329978 position_value:  500.0
#
# Day  6
#
# USD/JPY:
# Pre_fx_rate:  104.6149978637695 real_fx_rates:  139.7920074
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -4.27063114053249 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9352200031280518 real_fx_rates:  0.931699991
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -1.7011983635405936 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7907800078392029 real_fx_rates:  0.805679977
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.21720721005339116 entry_price:  0.805329978 position_value:  500.0
#
# Day  7
#
# USD/JPY:
# Pre_fx_rate:  148.4629974365234 real_fx_rates:  139.1269989
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -1.9011108705801947 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.948170006275177 real_fx_rates:  0.935000002
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.4599058749520535 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7692800164222717 real_fx_rates:  0.803409994
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  1.1948967615157213 entry_price:  0.805329978 position_value:  500.0
#
# Day  8
#
# USD/JPY:
# Pre_fx_rate:  143.8560028076172 real_fx_rates:  138.7480011
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.5405263456440467 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9429699778556824 real_fx_rates:  0.92930001
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.41430753885385224 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7249950170516968 real_fx_rates:  0.798340023
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  4.377805695957193 entry_price:  0.805329978 position_value:  500.0
#
# Day  9
#
# USD/JPY:
# Pre_fx_rate:  109.7779998779297 real_fx_rates:  140.2070007
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -5.737921401809135 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8379999995231628 real_fx_rates:  0.934700012
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.300542377654284 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8162099719047546 real_fx_rates:  0.80448997
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  0.5220748743455109 entry_price:  0.805329978 position_value:  500.0
#
# Day  10
#
# USD/JPY:
# Pre_fx_rate:  105.4329986572266 real_fx_rates:  139.3829956
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.8159403398558283 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8385199904441833 real_fx_rates:  0.93355
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.6886733436880497 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7897700071334839 real_fx_rates:  0.80430001
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  0.6402884416226678 entry_price:  0.805329978 position_value:  500.0
#
# Day  11
#
# USD/JPY:
# Pre_fx_rate:  145.7140045166016 real_fx_rates:  139.5269928
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.329053329958875 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8180630207061768 real_fx_rates:  0.934750021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.3271157316186937 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8290799856185913 real_fx_rates:  0.8046
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  0.453627889634579 entry_price:  0.805329978 position_value:  500.0
#
# Day  12
#
# USD/JPY:
# Pre_fx_rate:  161.5039978027344 real_fx_rates:  139.8990021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -4.649764760544985 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9361500144004822 real_fx_rates:  0.93392998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.891010094782488 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.710669994354248 real_fx_rates:  0.803480029
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  1.1512103183835987 entry_price:  0.805329978 position_value:  500.0
#
# Day  13
#
# USD/JPY:
# Pre_fx_rate:  135.8399963378906 real_fx_rates:  138.8630066
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.9541756529992688 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8285899758338928 real_fx_rates:  0.927410007
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  0.6038165382876082 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8133900165557861 real_fx_rates:  0.796209991
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  5.727124190281569 entry_price:  0.805329978 position_value:  500.0
#
# Day  14
#
# USD/JPY:
# Pre_fx_rate:  133.7109985351562 real_fx_rates:  139.3710022
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -2.7731557777374594 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8728200197219849 real_fx_rates:  0.930149972
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.8708240868495201 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8037999868392944 real_fx_rates:  0.794849992
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.592430084593873 entry_price:  0.805329978 position_value:  500.0
#
# Day  15
#
# USD/JPY:
# Pre_fx_rate:  141.8760070800781 real_fx_rates:  139.4600067
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.0904899562147947 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8611999750137329 real_fx_rates:  0.929109991
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.3121336578114519 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8000800013542175 real_fx_rates:  0.799019992
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  3.948578297900705 entry_price:  0.805329978 position_value:  500.0
#
# Day  16
#
# USD/JPY:
# Pre_fx_rate:  108.9909973144531 real_fx_rates:  140.177002
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -5.632146420138075 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8935999870300293 real_fx_rates:  0.926840007
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  0.9116843183485994 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8080499768257141 real_fx_rates:  0.793219984
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  7.633439805016247 entry_price:  0.805329978 position_value:  500.0
#
# Day  17
#
# USD/JPY:
# Pre_fx_rate:  109.7190017700195 real_fx_rates:  139.977005
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -4.925801205705106 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9360100030899048 real_fx_rates:  0.922249973
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  3.40471953583892 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8278599977493286 real_fx_rates:  0.789210021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  10.212716875778181 entry_price:  0.805329978 position_value:  500.0
#
# Day  18
#
# USD/JPY:
# Pre_fx_rate:  132.2839965820312 real_fx_rates:  140.2680054
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -5.952883536190858 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9049400091171265 real_fx_rates:  0.91358
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  8.182084765428362 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7821199893951416 real_fx_rates:  0.782119989
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  14.837869717200086 entry_price:  0.805329978 position_value:  500.0
#
# Day  19
#
# USD/JPY:
# Pre_fx_rate:  106.0299987792969 real_fx_rates:  141.8670044
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -11.521344282363662 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9391000270843506 real_fx_rates:  0.913900018
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  8.004135962277688 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8034800291061401 real_fx_rates:  0.779399991
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  16.634582563139862 entry_price:  0.805329978 position_value:  500.0
#
# Day  20
#
# USD/JPY:
# Pre_fx_rate:  106.5029983520508 real_fx_rates:  141.8990021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -11.631494412038498 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9454200267791748 real_fx_rates:  0.915390015
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  7.177248377567286 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.822160005569458 real_fx_rates:  0.781570017
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  15.20014872832564 entry_price:  0.805329978 position_value:  500.0
#
# Day  21
#
# USD/JPY:
# Pre_fx_rate:  144.4490051269531 real_fx_rates:  141.3350067
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -9.682666608597529 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9097300171852112 real_fx_rates:  0.915719986
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.994491872977419 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7889999747276306 real_fx_rates:  0.783370018
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  14.016339338634227 entry_price:  0.805329978 position_value:  500.0
#
# Day  22
#
# USD/JPY:
# Pre_fx_rate:  132.7899932861328 real_fx_rates:  141.6880035
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -10.904226976421457 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8421599864959717 real_fx_rates:  0.909699976
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  10.349567163229247 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7920500040054321 real_fx_rates:  0.782959998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  14.285519092381458 entry_price:  0.805329978 position_value:  500.0
#
# Day  23
#
# USD/JPY:
# Pre_fx_rate:  139.5529937744141 real_fx_rates:  143.0299988
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -15.493223929188677 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8296279907226562 real_fx_rates:  0.912500024
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  8.783536207337168 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7502400279045105 real_fx_rates:  0.784489989
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  13.282507930129842 entry_price:  0.805329978 position_value:  500.0
#
# Day  24
#
# USD/JPY:
# Pre_fx_rate:  109.7779998779297 real_fx_rates:  143.5410004
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -17.21805333049633 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9316999912261963 real_fx_rates:  0.916869998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.358578656425845 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7722799777984619 real_fx_rates:  0.785570025
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  12.57682470763825 entry_price:  0.805329978 position_value:  500.0
#
# Day  25
#
# USD/JPY:
# Pre_fx_rate:  105.4329986572266 real_fx_rates:  143.4600067
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -16.945487498014998 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9170399904251099 real_fx_rates:  0.916549981
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.535375728735123 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8080499768257141 real_fx_rates:  0.786660016
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.866601594252076 entry_price:  0.805329978 position_value:  500.0
#
# Day  26
#
# USD/JPY:
# Pre_fx_rate:  132.9290008544922 real_fx_rates:  143.8820038
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -18.362256781414086 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.910610020160675 real_fx_rates:  0.912639976
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  8.705514999268459 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7957000136375427 real_fx_rates:  0.784640014
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  13.184367117937915 entry_price:  0.805329978 position_value:  500.0
#
# Day  27
#
# USD/JPY:
# Pre_fx_rate:  144.2779998779297 real_fx_rates:  144.3890076
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -20.053467006445445 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8738999962806702 real_fx_rates:  0.916100025
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.784168027939989 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8321800231933594 real_fx_rates:  0.790979981
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  9.071024137588097 entry_price:  0.805329978 position_value:  500.0
#
# Day  28
#
# USD/JPY:
# Pre_fx_rate:  104.3089981079102 real_fx_rates:  144.7799988
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -21.349605094761113 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9479100108146667 real_fx_rates:  0.920130014
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  4.564552765474718 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7110499739646912 real_fx_rates:  0.792729974
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  7.947223148648055 entry_price:  0.805329978 position_value:  500.0
#
# Day  29
#
# USD/JPY:
# Pre_fx_rate:  136.4309997558594 real_fx_rates:  144.397995
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -20.08333910730546 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.944599986076355 real_fx_rates:  0.916800022
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.397227158879824 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7159500122070312 real_fx_rates:  0.787819982
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.112942296505445 entry_price:  0.805329978 position_value:  500.0
#
# Day  30
#
# USD/JPY:
# Pre_fx_rate:  130.7070007324219 real_fx_rates:  144.5839996
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -20.70074287805214 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8833000063896179 real_fx_rates:  0.91632998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  6.656989439546682 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7539700269699097 real_fx_rates:  0.787840009
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.099949736114503 entry_price:  0.805329978 position_value:  500.0
#
# Day  31
#
# USD/JPY:
# Pre_fx_rate:  136.3170013427734 real_fx_rates:  144.4060059
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -20.10996240704136 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8496999740600586 real_fx_rates:  0.91869998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  5.34995004571572 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7313399910926819 real_fx_rates:  0.786310017
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  12.094441498129813 entry_price:  0.805329978 position_value:  500.0
#
# Day  32
#
# USD/JPY:
# Pre_fx_rate:  156.8910064697266 real_fx_rates:  144.4889984
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -20.385604666216587 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8392080068588257 real_fx_rates:  0.92110002
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  4.033198262225645 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8314800262451172 real_fx_rates:  0.787119985
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.567482307033487 entry_price:  0.805329978 position_value:  500.0
#
# Day  33
#
# USD/JPY:
# Pre_fx_rate:  133.3470001220703 real_fx_rates:  143.951004
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -18.593120753780916 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9116299748420715 real_fx_rates:  0.918219984
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  5.614119807699583 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7110499739646912 real_fx_rates:  0.784759998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  13.1059050234617 entry_price:  0.805329978 position_value:  500.0
#
# Day  34
#
# USD/JPY:
# Pre_fx_rate:  143.8890075683594 real_fx_rates:  142.2089996
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -12.696075530229615 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8815699815750122 real_fx_rates:  0.911599994
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  9.28586228139006 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7878999710083008 real_fx_rates:  0.77888
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  16.979494915776456 entry_price:  0.805329978 position_value:  500.0
#
# Day  35
#
# USD/JPY:
# Pre_fx_rate:  115.2239990234375 real_fx_rates:  141.2969971
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -9.550768789834342 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9487900137901306 real_fx_rates:  0.908599973
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  10.96742548549475 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7164999842643738 real_fx_rates:  0.777320027
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  18.017000737844054 entry_price:  0.805329978 position_value:  500.0
#
# Day  36
#
# USD/JPY:
# Pre_fx_rate:  106.8939971923828 real_fx_rates:  140.1179962
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -5.423960666088876 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9174699783325195 real_fx_rates:  0.907930017
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.344465219944402 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7423999905586243 real_fx_rates:  0.773109972
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  20.837919032817734 entry_price:  0.805329978 position_value:  500.0
#
# Day  37
#
# USD/JPY:
# Pre_fx_rate:  134.6280059814453 real_fx_rates:  138.3150024
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  1.0230444821219724 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8485999703407288 real_fx_rates:  0.897300005
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  17.402191477754467 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7965099811553955 real_fx_rates:  0.769450009
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  23.315334706819076 entry_price:  0.805329978 position_value:  500.0
#
# Day  38
#
# USD/JPY:
# Pre_fx_rate:  134.0839996337891 real_fx_rates:  138.0749969
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  1.8939355847996036 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8422999978065491 real_fx_rates:  0.890990019
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  21.06643071161051 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8081600069999695 real_fx_rates:  0.761699975
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  28.639887378229187 entry_price:  0.805329978 position_value:  500.0
#
# Day  39
#
# USD/JPY:
# Pre_fx_rate:  134.0440063476562 real_fx_rates:  138.6820068
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.3028496700409678 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8365300297737122 real_fx_rates:  0.890649974
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  21.265370856003653 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7448999881744385 real_fx_rates:  0.763930023
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  27.096693253015356 entry_price:  0.805329978 position_value:  500.0
#
# Day  40
#
# USD/JPY:
# Pre_fx_rate:  109.9150009155273 real_fx_rates:  138.7290039
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.4721316246688526 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8973000049591064 real_fx_rates:  0.889869988
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  21.722268714157426 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7811999917030334 real_fx_rates:  0.765009999
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  26.352583007218932 entry_price:  0.805329978 position_value:  500.0
#
# Day  41
#
# USD/JPY:
# Pre_fx_rate:  156.9730072021484 real_fx_rates:  139.0269928
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -1.5428140656724898 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.883899986743927 real_fx_rates:  0.890559971
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  21.318051695813352 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8392599821090698 real_fx_rates:  0.767159998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  24.877457179408317 entry_price:  0.805329978 position_value:  500.0
#
# Day  42
#
# USD/JPY:
# Pre_fx_rate:  109.9440002441406 real_fx_rates:  139.5980072
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -3.5817130203274132 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.918429970741272 real_fx_rates:  0.892440021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  20.21982214533612 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7954699993133545 real_fx_rates:  0.772809982
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  21.040098314879163 entry_price:  0.805329978 position_value:  500.0
#
# Day  43
#
# USD/JPY:
# Pre_fx_rate:  148.3209991455078 real_fx_rates:  139.8639984
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -4.525793679869522 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9214000105857849 real_fx_rates:  0.897899985
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  17.05646147215384 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7508500218391418 real_fx_rates:  0.776859999
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  18.323751407362604 entry_price:  0.805329978 position_value:  500.0
#
# Day  44
#
# USD/JPY:
# Pre_fx_rate:  149.1600036621094 real_fx_rates:  141.75
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -11.118140388007014 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9192900061607361 real_fx_rates:  0.898850024
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  16.509958951728308 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8446199893951416 real_fx_rates:  0.777999997
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  17.56425520911663 entry_price:  0.805329978 position_value:  500.0
#
# Day  45
#
# USD/JPY:
# Pre_fx_rate:  118.2180023193359 real_fx_rates:  141.5220032
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -10.33053494822206 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9454200267791748 real_fx_rates:  0.903900027
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  13.624267211134834 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8024500012397766 real_fx_rates:  0.780480027
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  15.919658505239356 entry_price:  0.805329978 position_value:  500.0
#
# Day  46
#
# USD/JPY:
# Pre_fx_rate:  151.64599609375 real_fx_rates:  140.9129944
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -8.214243157123594 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9429699778556824 real_fx_rates:  0.904940009
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  13.033996046913641 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7999740242958069 real_fx_rates:  0.775560021
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  19.192555182005673 entry_price:  0.805329978 position_value:  500.0
#
# Day  47
#
# USD/JPY:
# Pre_fx_rate:  136.0449981689453 real_fx_rates:  140.3670044
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -6.301328462346244 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9783700108528137 real_fx_rates:  0.902660012
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  14.329850473092643 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7185500264167786 real_fx_rates:  0.773559988
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  20.534923272168978 entry_price:  0.805329978 position_value:  500.0
#
# Day  48
#
# USD/JPY:
# Pre_fx_rate:  106.5029983520508 real_fx_rates:  138.8639984
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -0.957739958033651 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8544600009918213 real_fx_rates:  0.910849988
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  9.705215037012207 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.8806399703025818 real_fx_rates:  0.78162998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  15.16062498012167 entry_price:  0.805329978 position_value:  500.0
#
# Day  49
#
# USD/JPY:
# Pre_fx_rate:  161.6069946289062 real_fx_rates:  140.7579956
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -7.672702324271997 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.9052000045776367 real_fx_rates:  0.907090008
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  11.817994802562135 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7844700217247009 real_fx_rates:  0.777970016
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  17.584200828634444 entry_price:  0.805329978 position_value:  500.0
#
# Day  50
#
# USD/JPY:
# Pre_fx_rate:  113.9619979858398 real_fx_rates:  142.322998
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  -13.086398025426643 entry_price:  138.5980072 position_value:  500.0
#
# USD/EUR:
# Pre_fx_rate:  0.8336399793624878 real_fx_rates:  0.909290016
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  10.579661967826993 entry_price:  0.928529978 position_value:  500.0
#
# USD/GBP:
# Pre_fx_rate:  0.7168499827384949 real_fx_rates:  0.77917999
# Capital:  1000.0 available_margin:  900.0 position_size:  -10.0 leverage:  5
# floating_pnl:  16.780454025776443 entry_price:  0.805329978 position_value:  500.0
#
# Final Results:
# USD/JPY:  capital 986.9136019745733
# USD/EUR:  capital 1010.579661967827
# USD/GBP:  capital 1016.7804540257764
# Rate of Return:  1.0047579059893923

# %% [markdown]
# **Download the datasets**

# %%
import yfinance as yf # 資料來源： Yahoo Finance
import numpy as np

# Define USD-based currency pairs to download (Yahoo Finance ticker format)
symbols = ['USDJPY=X', 'EURUSD=X', 'GBPUSD=X']

# Download historical FX data
fx_data = {}
for symbol in symbols:
    data = yf.download(symbol, period="6y", interval="1d")
    fx_data[symbol] = data['Close']
    print(f"{symbol} - {len(data)} rows downloaded.")

# Convert to pure numpy arrays
fx_numpy_list = [fx_data[s].to_numpy() for s in symbols]

# Align all currency pairs to the same length
min_len = min(len(arr) for arr in fx_numpy_list)
fx_numpy_list = [arr[-min_len:] for arr in fx_numpy_list]

# Combine into shape (3, N) → each currency pair is one row (dimension)
fx_combined = np.stack(fx_numpy_list, axis=0)
fx_data = fx_combined.reshape(3, -1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10768\1995630283.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="6y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# C:\Users\HP\AppData\Local\Temp\ipykernel_10768\1995630283.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="6y", interval="1d")
# USDJPY=X - 1564 rows downloaded.
# [*********************100%***********************]  1 of 1 completed
# C:\Users\HP\AppData\Local\Temp\ipykernel_10768\1995630283.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="6y", interval="1d")
# EURUSD=X - 1564 rows downloaded.
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X - 1565 rows downloaded.

# %%
import pandas as pd

# Transpose → shape becomes (N, 3), suitable for DataFrame format
fx_data = fx_data.T  # Example: shape (N, 3), N = number of days

# Define currency pair column names (without "=X" for cleaner column names)
symbols = ['USDJPY', 'EURUSD', 'GBPUSD']

# Convert to DataFrame
df = pd.DataFrame(fx_data, columns=symbols)

# Save to Excel
df.to_excel('fx_data.xlsx', index=False)

print("Saved to fx_data.xlsx")
# Out:
# Saved to fx_data.xlsx

# %% [markdown]
# **Train Process**

# %% [markdown]
# ***Step 1：切訓練集 + 測試集（預測 horizon = 1***

# %%
# 自動依照比例切分訓練集與測試集
from sklearn.preprocessing import MinMaxScaler

# Step 1: 檢查資料長度
num_days = fx_data.shape[0]
print(f"共有 {num_days} 天的資料")

# Step 2: 切分比例（例如：80% 訓練）
train_ratio = 0.8
train_days = int(num_days * train_ratio)
print(f"訓練集長度: {train_days} 天")
print(f"測試集長度: {num_days - train_days} 天")

# Step 3: 正規化資料
scaler = MinMaxScaler()
fx_scaled = scaler.fit_transform(fx_data)  # shape: (N, 3)

# Step 4: 切出訓練集
window_size = 30
X_train, y_train = [], []
for i in range(train_days - window_size):
    X_train.append(fx_scaled[i:i+window_size])
    y_train.append(fx_scaled[i+window_size])
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 共有 1564 天的資料
# 訓練集長度: 1251 天
# 測試集長度: 313 天

# %% [markdown]
# *** Step 2：建立並訓練模型（用 LSTM 為例) ***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import Huber

model = Sequential()
model.add(LSTM(64, input_shape=(window_size, 3)))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(3))

model.compile(optimizer='adam', loss=Huber(delta=1.0))

callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('best_lstm_model.h5', save_best_only=True)
]

model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# c:\Users\HP\anaconda3\envs\mll\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0476 - val_loss: 0.0029
# Epoch 2/100
# 31/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - val_loss: 0.0013
# Epoch 3/100
# 32/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 9.6799e-04
# Epoch 4/100
# 27/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - val_loss: 4.4964e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - val_loss: 6.0675e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 6.0416e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 5.7332e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 5.2107e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 4.9057e-04

# %% [markdown]
# ***Step 3：開始做 Rolling 預測 + 驗證***

# %%
preds = []
true_vals = []

for i in range(train_days, len(fx_scaled) - 1):
    input_seq = fx_scaled[i - window_size:i]  # 拿前30天做預測
    input_seq = input_seq.reshape(1, window_size, 3)

    pred_scaled = model.predict(input_seq, verbose=0)[0]
    true_scaled = fx_scaled[i]

    # 還原成實際價格
    pred_real = scaler.inverse_transform([pred_scaled])[0]
    true_real = scaler.inverse_transform([true_scaled])[0]

    preds.append(pred_real)
    true_vals.append(true_real)

# %% [markdown]
# ***Step 4：計算誤差指標（RMSE、MAE)***

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

preds = np.array(preds)
true_vals = np.array(true_vals)

rmse = np.sqrt(mean_squared_error(true_vals, preds))
mae = mean_absolute_error(true_vals, preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# RMSE: 1.2567
# MAE: 0.6120

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
import os

preds = np.array(preds)
true_vals = np.array(true_vals)

rmse = np.sqrt(mean_squared_error(true_vals, preds))
mae = mean_absolute_error(true_vals, preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")

# 儲存圖表
currency_names = ['USDJPY', 'EURUSD', 'GBPUSD']
os.makedirs("results", exist_ok=True)

for i in range(3):
    plt.figure(figsize=(10, 4))
    plt.plot([t[i] for t in true_vals], label='True')
    plt.plot([p[i] for p in preds], label='Predicted')
    plt.title(f"Rolling Prediction - {currency_names[i]}")
    plt.xlabel("Days")
    plt.ylabel("Exchange Rate")
    plt.legend()
    plt.grid(True)
    
    # 動態編號檔名
    base_filename = f"rolling_prediction_{currency_names[i]}"
    filename = f"{base_filename}.png"
    counter = 1
    while os.path.exists(os.path.join("results", filename)):
        filename = f"{base_filename}_{counter}.png"
        counter += 1

    plt.savefig(os.path.join("results", filename))
    plt.close()
# Out:
# RMSE: 1.2567
# MAE: 0.6120
